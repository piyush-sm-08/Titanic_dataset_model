# %%
import pandas  as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../data/Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # CATEGORICAL DATA

# %% [markdown]
# a) countplot

# %%
sns.countplot(data=df , x='Survived')
# df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data=df , x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# sns.countplot(data=df , x='Embarked')
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# b) Pie chart

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

df['Sex'].value_counts().plot(
    kind='pie',
    autopct='%1.2f%%',
    startangle=90,
    figsize=(4,6),
    shadow=True
)

plt.ylabel("")  
plt.title("Survival Distribution")
plt.show()

# %% [markdown]
# # NUMERICAL DATA :

# %% [markdown]
# a) Histogram

# %%
plt.hist(df['Age'],bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(data=df, x='Age', bins=20, kde=True)    # kernel density estimaton..
plt.show()

# %% [markdown]
# b) Distplot

# %%
sns.distplot(df['Age'])        # y-axis gives you, probability of getting age..in the range..
# Out:
# C:\Users\PIYUSH\AppData\Local\Temp\ipykernel_25056\689340541.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])        # y-axis gives you, probability of getting age..in the range..
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c) Boxplot :

# %%
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min() , df['Age'].max()
# Out:
# (np.float64(0.42), np.float64(80.0))

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df['Age'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    20.125
# 0.50    28.000
# 0.75    38.000
# Name: Age, dtype: float64

# %% [markdown]
# to check whether the data is skewed or not

# %%
df['Age'].skew(  )
# Out:
# np.float64(0.38910778230082704)

# %%
sns.barplot(data=df , x='Pclass', y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(data=df , x='Pclass', y='Fare')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data=df , x='Pclass', y='Fare' ,hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(data=df , x='Sex' , y='Age' , hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.histplot(
    data=df,
    x='Age',
    hue='Survived',
    kde=True,
    element='step',
    stat='density',
    common_norm=False
)
plt.show()

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\PIYUSH\AppData\Local\Temp\ipykernel_25056\455601345.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# C:\Users\PIYUSH\AppData\Local\Temp\ipykernel_25056\455601345.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
pd.crosstab(df['Pclass'], df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
plt.figure(figsize=(4, 3))  # Adjust width and height as needed
sns.heatmap(pd.crosstab(df['Pclass'], df['Survived']), annot=True, fmt='d')
plt.show()

# %%
df.groupby('Pclass').mean(numeric_only=True)['Survived'] * 100
# titanic.groupby('Pclass')['Survived'].mean() * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(df.groupby('Pclass').mean(numeric_only=True)['Survived'] * 100).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
plt.figure(figsize=(4, 3))  # Adjust width and height as needed
sns.heatmap(pd.crosstab(df['Sex'], df['Survived']), annot=True, fmt='d')
plt.show()

# %%
pd.crosstab(df['SibSp'],df['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(df['Parch'],df['Survived']))
